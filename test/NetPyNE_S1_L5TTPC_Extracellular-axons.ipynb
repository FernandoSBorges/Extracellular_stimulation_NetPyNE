# %%
import json
import numpy as np
import os
import sys
from matplotlib import pyplot as plt

rootFolder = os.getcwd()
os.chdir(rootFolder)
print(rootFolder)
folder = os.listdir('WeiseEtAl2023/cells/')
folder = sorted(folder)

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# /home/fernando/Dropbox/Extracellular_stimulation_NetPyNE/test

# %%
folder[15:20]
# Out:
# ['L5_TTPC2_cADpyr232_1',
#  'L5_TTPC2_cADpyr232_2',
#  'L5_TTPC2_cADpyr232_3',
#  'L5_TTPC2_cADpyr232_4',
#  'L5_TTPC2_cADpyr232_5']

# %%
def loadTemplateName(cellnumber):     
    f = open(outFolder+'/template.hoc', 'r')
    for line in f.readlines():
        if 'begintemplate' in line:
            templatename = str(line)     
    templatename=templatename[14:-1]    
    return templatename

# %%
cellnumber = 15 
cellName = folder[cellnumber]
outFolder = rootFolder+'/WeiseEtAl2023/cells/'+folder[cellnumber]
cellTemplateName = loadTemplateName(cellnumber)
print ("CellNumber = %d" % cellnumber)
print ("CellName = %s" % cellName)
print ("TemplateName = %s" % cellTemplateName)

with open(outFolder + '/current_amps.dat') as current_file:
    current_content = current_file.read()

holding_current, step1_current, step2_current, step3_current = [float(x) for x in current_content.split()]
# step1_current = step2_current
print ('load step1_current from current_amps.dat = %s' % step1_current)
# Out:
# CellNumber = 15
# CellName = L5_TTPC2_cADpyr232_1
# TemplateName = cADpyr232_L5_TTPC2_8052133265
# load step1_current from current_amps.dat = 0.5930628

# %%
holding_current,  holding_current + step1_current/1.,  holding_current + step2_current/1.,  holding_current + step3_current/1.
# Out:
# (-0.286011, 0.3070518, 0.3564737, 0.4058956)

# %%
holding_current,  holding_current + step1_current/1.2,  holding_current + step2_current/1.3,  holding_current + step3_current/1.4
# Out:
# (-0.286011, 0.208208, 0.208208, 0.20820800000000006)

# %%
step1_current = holding_current + step1_current/1.25
step1_current
# Out:
# 0.18843924

# %%
# os.chdir(rootFolder)
# !nrnivmodl WeiseEtAl2023/mechanisms/

# %%
ls -li
# Out:
# total 18852
# 23073807 -rwxr--r-- 1 fernando fernando    1956 Jun  4 12:25 cell_modification_parameters.py*
# 23090405 -rwxr--r-- 1 fernando fernando    1391 Jun  5 18:06 cellwrapper3.py*
# 23073725 -rwxr--r-- 1 fernando fernando   52075 Jun  5 12:34 cellwrapperTMSlike.py*
# 23158016 -rw-r--r-- 1 fernando fernando  477034 Apr 15 11:38 Extracellular_stimulation_NetPyNE_3_Sections.ipynb
# 23090471 -rw-r--r-- 1 fernando fernando  164806 Jun  5 18:59 Fig_comparison_traces_soma_voltage_4steps_exp_L5_TTPC2_cADpyr232_1.png
# 23869999 drwxr-xr-x 2 fernando fernando    4096 May 10 23:46 HallermannEtAl2012/
# 23090406 -rw-r--r-- 1 fernando fernando 3844940 Jun  5 18:41 L5_TTPC2_cADpyr232_1_BBP_cellParams.json
# 23090476 -rw-r--r-- 1 fernando fernando 4753980 Jun  5 23:30 L5_TTPC2_cADpyr232_1_cellParams.json
# 23090469 -rw-r--r-- 1 fernando fernando 5016364 Jun  5 23:30 L5_TTPC2_cADpyr232_1_cellParams.pkl
# 23157922 -rw-r--r-- 1 fernando fernando  154612 Apr 15 11:38 LFPy_extracellular-current-stimulation.ipynb
# 23167964 -rw-r--r-- 1 fernando fernando 1669892 May 28 15:31 NetPyNE_S1_L1_NGC-DA_bNAC219_3_Extracellular.ipynb
# 23090382 -rw-r--r-- 1 fernando fernando   32223 Jun  5 23:43 NetPyNE_S1_L5TTPC_Extracellular-axons.ipynb
# 23090184 -rw-r--r-- 1 fernando fernando 1936537 Jun  5 22:09 NetPyNE_S1_L5TTPC_Extracellular.ipynb
# 23872410 -rw-r--r-- 1 fernando fernando 1139016 May 16 19:41 NetPyNE_S1_NETWORK_Extracellular.ipynb
# 24510803 drwxr-xr-x 2 fernando fernando    4096 Jun  5 21:50 old_morpho/
# 23090465 -rwxr--r-- 1 fernando fernando   10608 Jun  5 18:32 plot_TMS_Cell.py*
# 24514268 drwxrwxr-x 2 fernando fernando    4096 Jun  5 21:58 __pycache__/
# 23876676 drwxr-xr-x 4 fernando fernando    4096 May 28 18:35 TMS-Neuro-Sim/
# 23870005 drwxr-xr-x 5 fernando fernando    4096 Apr 15 19:29 WeiseEtAl2023/
# 23886014 drwxrwxr-x 3 fernando fernando    4096 Jun  5 22:03 x86_64/

# %%
from netpyne import sim, specs
import pickle

cfg = specs.SimConfig()     

cfg.duration = 1000 ## Duration of the sim, in ms  
cfg.dt = 0.025
cfg.seeds = {'conn': 4321, 'stim': 1234, 'loc': 4321} 
cfg.hParams = {'celsius': 34, 'v_init': -70}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True
cfg.cvode_active = False
cfg.cvode_atol = 1e-6
cfg.cache_efficient = True
cfg.printRunTime = 0.5

cfg.includeParamsLabel = False
cfg.printPopAvgRates = True
cfg.checkErrors = False

allpops = ['L5_TTPC']

cfg.recordCells = allpops  # which cells to record from
cfg.recordTraces = {'V_soma': {'sec':'soma_0', 'loc':0.5, 'var':'v'},
                    'V_axon_0': {'sec':'axon_0', 'loc':0.5, 'var':'v'},
                    'V_axon_1': {'sec':'Myelin_0', 'loc':0.5, 'var':'v'},
                    # 'V_apic_0': {'sec':'apic_0', 'loc':0.5, 'var':'v'},
                    'V_apic_5': {'sec':'apic_5', 'loc':0.5, 'var':'v'},
                    'V_apic_95': {'sec':'apic_95', 'loc':0.5, 'var':'v'},
                    # 'V_apic_100': {'sec':'apic_100', 'loc':0.5, 'var':'v'},
                    # 'V_dend_8_1': {'sec':'dend_8', 'loc':0.1, 'var':'v'},
                    # 'V_dend_8_3': {'sec':'dend_8', 'loc':0.3, 'var':'v'},
                    # 'V_dend_8_5': {'sec':'dend_8', 'loc':0.5, 'var':'v'},
                    # 'V_dend_8_7': {'sec':'dend_8', 'loc':0.7, 'var':'v'},
                    # 'V_dend_8_9': {'sec':'dend_8', 'loc':0.9, 'var':'v'},                    
                    'V_dend_5': {'sec':'dend_5', 'loc':0.5, 'var':'v'},
                    'V_dend_65': {'sec':'dend_65', 'loc':0.5, 'var':'v'},
                    # 'V_dend_70': {'sec':'dend_70', 'loc':0.5, 'var':'v'},
                    }



## Dict with traces to record
cfg.recordStim = True
cfg.recordTime = True
cfg.recordStep = 0.025         


cfg.recordLFP = [[0, y, 0] for y in [-400]] # 1 elec on skull


cfg.simLabel = 'S1_L5_TTPC'
cfg.saveFolder = '.'
cfg.savePickle = False         	## Save pkl file
cfg.saveJson = False           	## Save json file
cfg.saveDataInclude = ['simConfig', 'netParams'] ## 'simData' , 'simConfig', 'netParams'
cfg.backupCfgFile = None 		##  
cfg.gatherOnlySimData = False	##  
cfg.saveCellSecs = True			##  
cfg.saveCellConns = False		##  

cfg.analysis['plotTraces'] = {'include': ['L5_TTPC'], 'figSize': (12, 4), 'saveFig': False, 'overlay': True, 'oneFigPer': 'cell'}  # Plot recorded traces for this list of cells


#------------------------------------------------------------------------------
# Current inputs 
#------------------------------------------------------------------------------
cfg.addIClamp = 1

cfg.IClamp1 = {'pop': 'L5_TTPC', 'sec': 'soma_0', 'loc': 0.5, 'start': 1000, 'dur': 1000, 'amp': step1_current}
# cfg.IClamp2 = {'pop': 'L5_TTPC', 'sec': 'apic_98', 'loc': 0.5, 'start': 700, 'dur': 25, 'amp': step1_current}
# cfg.IClamp3 = {'pop': 'L5_TTPC', 'sec': 'apic_99', 'loc': 0.5, 'start': 900, 'dur': 25, 'amp': step1_current}
# cfg.IClamp4 = {'pop': 'L5_TTPC', 'sec': 'apic_100', 'loc': 0.5, 'start': 1100, 'dur': 25, 'amp': step1_current}


netParams = specs.NetParams()   # object of class NetParams to store the network parameters

#------------------------------------------------------------------------------
# Cell parameters
#------------------------------------------------------------------------------
#StochKv_deterministic.mod
cellName = folder[cellnumber]
cellTemplateName = loadTemplateName(cellnumber)
cellNumber = 1
cellRule = netParams.importCellParams(label=cellName + '_rule', somaAtOrigin=False,
    conds={'cellType': cellName, 'cellModel': 'HH_full'},
    fileName='cellwrapper3.py',
    cellName='loadCell_L5_TTPC2_cADpyr',
    cellInstance = True,
    cellArgs={'cellNumber': cellNumber})

#------------------------------------------------------------------------------
# Population parameters
#------------------------------------------------------------------------------

## Population parameters
# pyr_positions = [[x , y , 0] for x in range(100,1100,300) for y in range(100,1100,300)]
# pyr_positions = [[x-857 , x , 0] for x in range(857,1382,250)]
pyr_positions = [[x , 857 , 210] for x in range(210,1382,2500)]
cellsList = [{'x': x, 'y': y, 'z': z} for x,y,z in pyr_positions]
netParams.popParams['L5_TTPC'] = {'cellType': cellName, 'cellModel': 'HH_full', 'cellsList': cellsList} 


# #------------------------------------------------------------------------------
# #  extracellular mechs
# #------------------------------------------------------------------------------
# for celltyp in netParams.cellParams.keys():
#     label = []
#     for secname in netParams.cellParams[celltyp]['secs'].keys():
#         netParams.cellParams[celltyp]['secs'][secname]['mechs']['extracellular'] = {}

#-----------------------------------------------------------------------------------#
# for cellMe in netParams.cellParams.keys():
#     axon_pt3d_x, axon_pt3d_y, axon_pt3d_z, soma_pt3d_diam =  netParams.cellParams[cellMe]['secs']['soma_0']['geom']['pt3d'][-1]
#     axon_pt3d_diam =  netParams.cellParams[cellMe]['secs']['axon_0']['geom']['diam']
#     axon_pt3d_L =  netParams.cellParams[cellMe]['secs']['axon_0']['geom']['L']

#     netParams.cellParams[cellMe]['secs']['axon_0']['geom']['pt3d'] = [(axon_pt3d_x, axon_pt3d_y, axon_pt3d_z, axon_pt3d_diam),
#                                                                       (axon_pt3d_x, axon_pt3d_y+axon_pt3d_L/2.0, axon_pt3d_z, axon_pt3d_diam),
#                                                                       (axon_pt3d_x, axon_pt3d_y+axon_pt3d_L, axon_pt3d_z, axon_pt3d_diam)]

#     axon1_pt3d_x, axon1_pt3d_y, axon1_pt3d_z, soma_pt3d_diam =  netParams.cellParams[cellMe]['secs']['axon_0']['geom']['pt3d'][-1]
#     axon1_pt3d_diam =  netParams.cellParams[cellMe]['secs']['axon_1']['geom']['diam']
#     axon1_pt3d_L =  netParams.cellParams[cellMe]['secs']['axon_1']['geom']['L']

#     netParams.cellParams[cellMe]['secs']['axon_1']['geom']['pt3d'] = [(axon1_pt3d_x, axon1_pt3d_y, axon1_pt3d_z, axon1_pt3d_diam),
#                                                                           (axon1_pt3d_x, axon1_pt3d_y+axon1_pt3d_L/2.0, axon1_pt3d_z, axon1_pt3d_diam),
#                                                                           (axon1_pt3d_x, axon1_pt3d_y+axon1_pt3d_L, axon1_pt3d_z, axon1_pt3d_diam)] 
        

#------------------------------------------------------------------------------
# Current inputs (IClamp)
#------------------------------------------------------------------------------
if cfg.addIClamp:
     for key in [k for k in dir(cfg) if k.startswith('IClamp')]:
        params = getattr(cfg, key, None)
        [pop,sec,loc,start,dur,amp] = [params[s] for s in ['pop','sec','loc','start','dur','amp']]

        #cfg.analysis['plotTraces']['include'].append((pop,0))  # record that pop

        # add stim source
        netParams.stimSourceParams[key] = {'type': 'IClamp', 'delay': start, 'dur': dur, 'amp': amp}

        # connect stim source to target
        netParams.stimTargetParams[key+'_'+pop] =  {
            'source': key, 
            'conds': {'pop': pop},
            'sec': sec, 
            'loc': loc}

        
# netParams.rotateCellsRandomly = [0, 6.2832]
# sim.createSimulateAnalyze(netParams, cfg)
# Out:
# False
# True

# %%
celltyp = 'L5_TTPC2_cADpyr232_1_rule'
netParams.cellParams[celltyp]['secLists']['all'] = list(netParams.cellParams[celltyp]['secs'].keys())
len(netParams.cellParams[celltyp]['secLists']['all'])
# Out:
# 976

# %%
netParams.cellParams[celltyp]['secLists']['all'] = list(netParams.cellParams[celltyp]['secs'].keys())
netParams.cellParams[celltyp]['secLists']['somatic'] = [sec for sec in list(netParams.cellParams[celltyp]['secs'].keys()) if 'soma' in sec]
netParams.cellParams[celltyp]['secLists']['apical'] = [sec for sec in list(netParams.cellParams[celltyp]['secs'].keys()) if 'apic' in sec]
netParams.cellParams[celltyp]['secLists']['basal'] = [sec for sec in laist(netParams.cellParams[celltyp]['secs'].keys()) if 'dend' in sec]
netParams.cellParams[celltyp]['secLists']['axonal'] = [sec for sec in list(netParams.cellParams[celltyp]['secs'].keys()) if 'Node' in sec or 'axon' in sec or 'y' in sec]

# %%
for celltyp in netParams.cellParams.keys():
    label = []
    for secname in netParams.cellParams[celltyp]['secs'].keys():
        netParams.cellParams[celltyp]['secs'][secname]['mechs']['extracellular'] = {}
        del netParams.cellParams[celltyp]['secs'][secname].mechs.xtra

# %%
netParams.cellParams[celltyp]['secs']['Node_113']['geom']['diam']
# Out:
# 1000.0

# %%
netParams.cellParams[celltyp]['secs']['Node_113']['geom']['diam'] = 1.0

# %%
netParams.cellParams[celltyp]['secs']['Node_113']['geom']['pt3d']
# Out:
# [(-22.136661529541016, -6.852905750274658, -709.5120239257812, 1000.0),
#  (-22.494400024414062, -7.216529846191406, -710.219970703125, 1000.0),
#  (-22.545791625976562, -7.267182350158691, -710.3250122070312, 1000.0)]

# %%
netParams.cellParams[celltyp]['secs']['Node_113']['geom']['pt3d'] = [(-22.136661529541016, -6.852905750274658, -709.5120239257812, 1.0),
 (-22.494400024414062, -7.216529846191406, -710.219970703125, 1.0),
 (-22.545791625976562, -7.267182350158691, -710.3250122070312, 1.0)]

# %%
# for celltyp in netParams.cellParams.keys():
#     label = []
#     for secname in netParams.cellParams[celltyp]['secs'].keys():
#         print(secname,netParams.cellParams[celltyp]['secs'][secname]['geom']['L'],netParams.cellParams[celltyp]['secs'][secname]['geom']['diam'])

# %%
netParams.saveCellParamsRule(label=cellName + '_rule', fileName=cellName+'_cellParams.pkl')
netParams.saveCellParamsRule(label=cellName + '_rule', fileName=cellName+'_cellParams.json')

# %%
cfg.verbose=True
sim.initialize(
    simConfig = cfg, 	
    netParams = netParams)  				# create network object and set cfg and net params
sim.net.createPops()               			# instantiate network populations
sim.net.createCells()              			# instantiate network cells based on defined populations
sim.net.defineCellShapes()  # in case some cells had stylized morphologies without 3d pts
sim.net.connectCells()            			# create connections between cells based on params
sim.net.addStims() 							# add network stimulation
sim.setupRecording()              			# setup variables to record for each cell (spikes, V traces, etc)
# Out:
# Start time:  2024-06-05 23:44:06.750004
#
# Creating network of 1 cell populations on 1 hosts...
# Distributed population of 1 cells on 1 hosts: {0: [0]}, next: 0
# Cell 0/0 (gid=0) of pop 0, on node 0,
# Instantiated 1 cells of population L5_TTPC
#   Number of cells on node 0: 1
#   Done; cell creation time = 0.17 s.
# Making connections...
#   Number of connections on node 0: 0
#   Done; cell connection time = 0.00 s.
# Adding stims...
#   Added IClamp1 IClamp to cell gid=0, sec=soma_0, loc=0.5, delay=1000, dur=1000, amp=0.18843924
#   Number of stims on node 0: 1
#   Done; cell stims creation time = 0.00 s.
#   Recording  V_soma from cell  0  with parameters:  {'sec': 'soma_0', 'loc': 0.5, 'var': 'v'}
# Vector[33040]
#   Recording  V_axon_0 from cell  0  with parameters:  {'sec': 'axon_0', 'loc': 0.5, 'var': 'v'}
# Vector[33041]
#   Recording  V_axon_1 from cell  0  with parameters:  {'sec': 'Myelin_0', 'loc': 0.5, 'var': 'v'}
# Vector[33042]
#   Recording  V_apic_5 from cell  0  with parameters:  {'sec': 'apic_5', 'loc': 0.5, 'var': 'v'}
# Vector[33043]
#   Recording  V_apic_95 from cell  0  with parameters:  {'sec': 'apic_95', 'loc': 0.5, 'var': 'v'}
# Vector[33044]
#   Recording  V_dend_5 from cell  0  with parameters:  {'sec': 'dend_5', 'loc': 0.5, 'var': 'v'}
# Vector[33045]
#   Recording  V_dend_65 from cell  0  with parameters:  {'sec': 'dend_65', 'loc': 0.5, 'var': 'v'}
# Vector[33046]
#   Recording  V_soma from cell  0  with parameters:  {'sec': 'soma_0', 'loc': 0.5, 'var': 'v'}
# Vector[33047]
#   Recording  V_axon_0 from cell  0  with parameters:  {'sec': 'axon_0', 'loc': 0.5, 'var': 'v'}
# Vector[33048]
#   Recording  V_axon_1 from cell  0  with parameters:  {'sec': 'Myelin_0', 'loc': 0.5, 'var': 'v'}
# Vector[33049]
#   Recording  V_apic_5 from cell  0  with parameters:  {'sec': 'apic_5', 'loc': 0.5, 'var': 'v'}
# Vector[33050]
#   Recording  V_apic_95 from cell  0  with parameters:  {'sec': 'apic_95', 'loc': 0.5, 'var': 'v'}
# Vector[33051]
#   Recording  V_dend_5 from cell  0  with parameters:  {'sec': 'dend_5', 'loc': 0.5, 'var': 'v'}
# Vector[33052]
#   Recording  V_dend_65 from cell  0  with parameters:  {'sec': 'dend_65', 'loc': 0.5, 'var': 'v'}
# Vector[33053]
#    Recording: spkt:
#    Recording: spkid:
#    Recording: stims:
#       cell_0
#    Recording: V_soma:
#       cell_0
#    Recording: V_axon_0:
#       cell_0
#    Recording: V_axon_1:
#       cell_0
#    Recording: V_apic_5:
#       cell_0
#    Recording: V_apic_95:
#       cell_0
#    Recording: V_dend_5:
#       cell_0
#    Recording: V_dend_65:
#       cell_0
#    Recording: t:
# Recording 8 traces of 8 types on node 0
# {spkt: Vector[33038], spkid: Vector[33039], stims: {cell_0: {}}, V_soma: {cell_0: Vector[33047]}, V_axon_0: {cell_0: Vector[33048]}, V_axon_1: {cell_0: Vector[33049]}, V_apic_5: {cell_0: Vector[33050]}, V_apic_95: {cell_0: Vector[33051]}, V_dend_5: {cell_0: Vector[33052]}, V_dend_65: {cell_0: Vector[33053]}, t: Vector[33054], LFP: array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]]), _repr_mimebundle_: {}}

# %%
def collect_pt3d(self, section):
        """        collect the pt3d info, for each section
        """
        n3dsec = 0
        r3dsec = np.zeros(3)
        for sec in [sec for secName, sec in self.secs.items() if section in secName]:
            sec['hObj'].push()
            n3d = int(neuron.h.n3d())  # get number of n3d points in each section
            # print("get number of n3d points in each section",n3d)
            r3d = np.zeros((3, n3d))  # to hold locations of 3D morphology for the current section
            n3dsec += n3d

            for i in range(n3d):
                r3dsec[0] += neuron.h.x3d(i)
                r3dsec[1] += neuron.h.y3d(i)
                r3dsec[2] += neuron.h.z3d(i)
            
            neuron.h.pop_section()

        r3dsec /= n3dsec
        
        return r3dsec
    
def getSecsPos(self, secList):
        """        Get Secs position
        """
        x3d, y3d, z3d = [], [], []
        
        for secName in secList:
            # print(secName)
            r3dsec = collect_pt3d(self, secName)
            # print(secName, r3dsec)
            
            x3d.append(r3dsec[0])
            y3d.append(r3dsec[1])
            z3d.append(r3dsec[2])
            
        return x3d, y3d, z3d
    
def insert_v_ext(self, v_ext, t_ext):

    self.t_ext = neuron.h.Vector(t_ext)
    self.v_ext = []
    for v in v_ext:
        self.v_ext.append(neuron.h.Vector(v))
    
    # play v_ext into e_extracellular reference
    i = 0
    for secName, sec in self.secs.items(): 
        # print(secName,i)
        for seg in sec['hObj']:
                self.v_ext[i].play(seg._ref_e_extracellular, self.t_ext)
        i += 1
  
def make_extracellular_stimuli(acs_params, self, secList):
    """ Function to calculate and apply external potential """
    x0, y0, z0 = acs_params['position']
    ext_field = np.vectorize(lambda x, y, z: 1 / (4 * np.pi *
                            (acs_params['sigma'] * 
                            np.sqrt((x0 - x)**2 + (y0 - y)**2 + (z0 - z)**2) + skull_attenuation)))

    stimstart = acs_params['stimstart']
    stimend = acs_params['stimend']
    stimdif = stimend-stimstart

    # MAKING THE EXTERNAL FIELD
    n_tsteps = int(stimdif / cfg.dt + 1)
    n_start = int(stimstart/cfg.dt)
    n_end = int(stimend/cfg.dt + 1)
    t = np.arange(start=n_start, stop=n_end) * cfg.dt
    pulse = acs_params['amp'] * 1000. * \
        np.sin(2 * np.pi * acs_params['frequency'] * t / 1000)

    totnsegs = len(secList)    
    v_cell_ext = np.zeros((totnsegs, n_tsteps))    
    v_cell_ext[:, :] = ext_field(getSecsPos(metype,secList)[0], -1*np.array(getSecsPos(metype, secList)[1]), 
                                 getSecsPos(metype,secList)[2]).reshape(totnsegs, 1) * pulse.reshape(1, n_tsteps)
    
    insert_v_ext(self, v_cell_ext, t)

    return v_cell_ext, self


# The parameters of the extracellular point current source
acs_params = {'position': [0.0, -1710.0, 0.0],  # um # y = [pia, bone]
              'amp': 250.,  # uA,
              'stimstart': 500,  # ms
              'stimend': 1500,  # ms
              'frequency': 5,  # Hz
              'sigma': 0.57  # decay constant S/m
              }

skull_attenuation = 0.01*710 #conductivity of bone(S/m) * thickness of rat skull um

#Add extracellular stim
for c,metype in enumerate(sim.net.cells):
    if 'presyn' not in metype.tags['pop']:
        print("\n", metype.tags)
        secList = [secs for secs in metype.secs.keys() if "pt3d" in metype.secs[secs]['geom']]
        # print(secList)
        v_cell_ext, cell = make_extracellular_stimuli(acs_params, metype,secList)


sim.runSim()                      			# run parallel Neuron simulation  
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
sim.analysis.plotShape()
# Out:
#  {'cellType': 'L5_TTPC2_cADpyr232_1', 'cellModel': 'HH_full', 'pop': 'L5_TTPC', 'x': 210, 'y': 857, 'z': 210, 'xnorm': 2.1, 'ynorm': 8.57, 'znorm': 2.1}
#
# Setting h global variables ...
#   h.celsius = 34
#   h.v_init = -70
#   h.tstop = 1000.0
# Minimum delay (time-step for queue exchange) is 10.00
# 0.0s
#
# Running simulation using NEURON for 1000.0 ms...
# 0.5s
# 1.0s
#   Done; run time = 293.77 s; real-time ratio: 0.00.
#
# Gathering data...
#   Done; gather time = 0.14 s.
#
# Analyzing...
#   Cells: 1
#   Connections: 0 (0.00 per cell)
#   Spikes: 0 (0.00 Hz)
#   Simulated time: 1.0 s; 1 workers
#   Run time: 293.77 s
#    L5_TTPC : 0.000 Hz
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
#   Done; plotting time = 0.80 s
#
# Total time = 296.28 s
# Plotting 3D cell shape ...
# (<Figure size 640x480 with 1 Axes>, {})

# %%
print(np.shape(v_cell_ext))
for v in v_cell_ext:
    plt.plot(v)
# Out:
# (976, 40001)

# %%
figure = plt.figure()
for c,metype in enumerate(sim.net.cells):
    if 'presyn' not in metype.tags['pop']:
        print("\n", metype.tags)
        plt.plot(0,-400,'b^')
        plt.plot(acs_params['position'][0],acs_params['position'][1],'ks')
        secList = [secs for secs in metype.secs.keys() if "pt3d" in metype.secs[secs]['geom']]
        plt.plot(np.array(getSecsPos(metype, secList)[0]),-1*np.array(getSecsPos(metype, secList)[1]),'o')
        # plt.plot(np.array(getSecsPos(metype, secList)[0]),-1*np.array(getSecsPos(metype, secList)[2]),'o')
        plt.ylim(2550,-1850)
        # print(np.array(getSecsPos(cell, secList)[0]).mean(axis=-1),-1*np.array(getSecsPos(cell, secList)[1]).mean(axis=-1),np.array(getSecsPos(cell, secList)[2]).mean(axis=-1))

figure = plt.figure()
for c,metype in enumerate(sim.net.cells):
    if 'presyn' not in metype.tags['pop']:
        print("\n", metype.tags)
        plt.plot(0,-400,'b^')
        plt.plot(acs_params['position'][0],acs_params['position'][1],'ks')
        secList = [secs for secs in metype.secs.keys() if "pt3d" in metype.secs[secs]['geom']]
        # plt.plot(np.array(getSecsPos(metype, secList)[0]),-1*np.array(getSecsPos(metype, secList)[1]),'o')
        plt.plot(np.array(getSecsPos(metype, secList)[0]),-1*np.array(getSecsPos(metype, secList)[2]),'o')
        plt.ylim(2550,-1850)
        # print(np.array(getSecsPos(cell, secList)[0]).mean(axis=-1),-1*np.array(getSecsPos(cell, secList)[1]).mean(axis=-1),np.array(getSecsPos(cell, secList)[2]).mean(axis=-1))
# Out:
#  {'cellType': 'L5_TTPC2_cADpyr232_1', 'cellModel': 'HH_full', 'pop': 'L5_TTPC', 'x': 210, 'y': 857, 'z': 210, 'xnorm': 2.1, 'ynorm': 8.57, 'znorm': 2.1}
#
#  {'cellType': 'L5_TTPC2_cADpyr232_1', 'cellModel': 'HH_full', 'pop': 'L5_TTPC', 'x': 210, 'y': 857, 'z': 210, 'xnorm': 2.1, 'ynorm': 8.57, 'znorm': 2.1}

# %%
sim.analysis.plotLFP(**{'plots': ['locations'], 
        'figSize': (12,12), 
        'saveData': False, 
        'saveFig': False, 'showFig': False, 'dpi': 300})

sim.analysis.plotLFP(**{'plots': ['timeSeries'], 
        'electrodes': [0], #'avg', 
        'timeRange': [350, cfg.duration], 
        'figSize': (12,4), 'saveFig': False, 'showFig': False})
# Out:
# Plotting LFP electrode locations...
# Plotting 3D cell shape ...
# Preparing LFP data...
# Plotting LFP time series...

# %%
sim.analysis.plotShape(includePre=['L5_TTPC'], includePost=['L5_TTPC'], includeAxon=False, showSyns=False, showElectrodes=[0],
    cvar= 'voltage', dist=0.6, elev=5, azim=90, 
    axisLabels=True, synStyle='o', 
    clim= [-80, -60], showFig=False, synSize=2)
sim.analysis.plotShape(includePre=['L5_TTPC'], includePost=['L5_TTPC'], includeAxon=True, showSyns=False, showElectrodes=False,
    cvar= 'voltage', dist=0.6, elev=5, azim=90, 
    axisLabels=True, synStyle='o', 
    clim= [-80, -60], showFig=False, synSize=2)
# Out:
# Plotting 3D cell shape ...
# Plotting 3D cell shape ...
# (<Figure size 640x480 with 2 Axes>, {})

# %%
sim.analysis.plotShape(includePre=['L5_TTPC'], includePost=['L5_TTPC'], includeAxon=False, showSyns=False, showElectrodes=[0],
    cvar= 'voltage', dist=0.6, elev=95, azim=-90, 
    axisLabels=True, synStyle='o', 
    clim= [-80, -60], showFig=False, synSize=2)
sim.analysis.plotShape(includePre=['L5_TTPC'], includePost=['L5_TTPC'], includeAxon=True, showSyns=False, showElectrodes=False,
    cvar= 'voltage', dist=0.6, elev=95, azim=-90, 
    axisLabels=True, synStyle='o', 
    clim= [-80, -60], showFig=False, synSize=2)
# Out:
# Plotting 3D cell shape ...
# Plotting 3D cell shape ...
# (<Figure size 640x480 with 2 Axes>, {})

# %%
sim.analysis.plotTraces(overlay=True, oneFigPer='trace', figSize=(24,3), fontSize=15, saveFig=False);
# Out:
# Plotting recorded cell traces ... trace

# %%
netParams.cellParams['L5_TTPC2_cADpyr232_1_rule']['secs']['soma_0']
# Out:
# {geom: {L: 26.11267539383973, nseg: 1, diam: 44.982421875, Ra: 100.0, cm: 1.0, pt3d: [(1.1156564950942993, -0.0, -14.01707649230957, 44.982421875), (1.1375269889831543, -0.0, -12.711626052856445, 44.982421875), (1.1593974828720093, -0.0, -11.406174659729004, 44.982421875), (1.1812679767608643, -0.0, -10.100724220275879, 44.982421875), (1.2031383514404297, -0.0, -8.795273780822754, 44.982421875), (1.2250088453292847, -0.0, -7.489823341369629, 44.982421875), (1.2468793392181396, -0.0, -6.184372901916504, 44.982421875), (1.2687498331069946, -0.0, -4.878921985626221, 44.982421875), (1.29062020778656, -0.0, -3.5734715461730957, 44.982421875), (1.312490701675415, -0.0, -2.2680208683013916, 44.982421875), (1.33436119556427, -0.0, -0.962570309638977, 44.982421875), (1.3562315702438354, -0.0, 0.3428802788257599, 44.982421875), (1.3781020641326904, -0.0, 1.6483309268951416, 44.982421875), (1.3999725580215454, -0.0, 2.9537813663482666, 44.982421875), (1.4218430519104004, -0.0, 4.259232044219971, 44.982421875), (1.4437134265899658, -0.0, 5.564682483673096, 44.982421875), (1.4655839204788208, -0.0, 6.870133399963379, 44.982421875), (1.4874544143676758, -0.0, 8.175583839416504, 44.982421875), (1.5093249082565308, -0.0, 9.481034278869629, 44.982421875), (1.5311952829360962, -0.0, 10.786484718322754, 44.982421875), (1.5530657768249512, -0.0, 12.091935157775879, 44.982421875)]}, topol: {}, mechs: {CaDynamics_E2: {gamma: 0.000609, decay: 210.485284, depth: 0.1, minCai: 0.0001}, Ca_HVA: {gCa_HVAbar: 0.000994}, Ca_LVAst: {gCa_LVAstbar: 0.000333}, Ih: {gIhbar: 8e-05}, NaTs2_t: {gNaTs2_tbar: 0.983955}, SK_E2: {gSK_E2bar: 0.008407}, SKv3_1: {gSKv3_1bar: 0.303472}, extracellular: {}, pas: {g: 3e-05, e: -75.0}}, ions: {ca: {e: 132.4579341637009, i: 5e-05, o: 2.0}, k: {e: -85.0, i: 54.4, o: 2.5}, na: {e: 50.0, i: 10.0, o: 140.0}}, _repr_mimebundle_: {}, _repr_html_: {}, _repr_markdown_: {}, _repr_svg_: {}, _repr_png_: {}, _repr_pdf_: {}, _repr_jpeg_: {}, _repr_latex_: {}, _repr_json_: {}, _repr_javascript_: {}}

# %%
for section in netParams.cellParams['L5_TTPC2_cADpyr232_1_rule']['secLists']['axonal']:
    print(section,'->',netParams.cellParams['L5_TTPC2_cADpyr232_1_rule']['secs'][section]['topol']['parentSec'])
# Out:
# axon_0 -> soma_0
# Myelin_0 -> axon_0
# Myelin_1 -> Node_0
# Myelin_2 -> Node_1
# Myelin_3 -> Node_2
# Myelin_4 -> Node_3
# Myelin_5 -> Node_4
# Myelin_6 -> Node_5
# Myelin_7 -> Node_6
# Myelin_8 -> Node_7
# Myelin_9 -> Node_8
# Myelin_10 -> Node_9
# Myelin_11 -> Unmyelin_0
# Myelin_12 -> Node_11
# Myelin_13 -> Node_12
# Myelin_14 -> Node_13
# Myelin_15 -> Node_14
# Myelin_16 -> Node_15
# Myelin_17 -> Node_16
# Myelin_18 -> Unmyelin_1
# Myelin_19 -> Unmyelin_1
# Myelin_20 -> Node_19
# Myelin_21 -> Node_20
# Myelin_22 -> Node_21
# Myelin_23 -> Node_21
# Myelin_24 -> Node_23
# Myelin_25 -> Node_24
# Myelin_26 -> Node_17
# Myelin_27 -> Node_26
# Myelin_28 -> Node_27
# Myelin_29 -> Node_28
# Myelin_30 -> Node_29
# Myelin_31 -> Node_30
# Myelin_32 -> Node_30
# Myelin_33 -> Node_29
# Myelin_34 -> Node_15
# Myelin_35 -> Node_34
# Myelin_36 -> Node_35
# Myelin_37 -> Node_13
# Myelin_38 -> Node_37
# Myelin_39 -> Node_38
# Myelin_40 -> Node_39
# Myelin_41 -> Node_40
# Myelin_42 -> Node_41
# Myelin_43 -> Node_42
# Myelin_44 -> Node_43
# Myelin_45 -> Node_44
# Myelin_46 -> Node_45
# Myelin_47 -> Node_46
# Myelin_48 -> Node_47
# Myelin_49 -> Node_48
# Myelin_50 -> Node_49
# Myelin_51 -> Node_47
# Myelin_52 -> Node_51
# Myelin_53 -> Node_52
# Myelin_54 -> Node_53
# Myelin_55 -> Node_54
# Myelin_56 -> Node_55
# Myelin_57 -> Node_39
# Myelin_58 -> Node_57
# Myelin_59 -> Node_58
# Myelin_60 -> Node_59
# Myelin_61 -> Node_60
# Myelin_62 -> Node_61
# Myelin_63 -> Node_61
# Myelin_64 -> Node_60
# Myelin_65 -> Node_64
# Myelin_66 -> Node_65
# Myelin_67 -> Node_66
# Myelin_68 -> Node_67
# Myelin_69 -> Node_12
# Myelin_70 -> Unmyelin_3
# Myelin_71 -> Unmyelin_4
# Myelin_72 -> Node_71
# Myelin_73 -> Node_72
# Myelin_74 -> Node_72
# Myelin_75 -> Node_74
# Myelin_76 -> Unmyelin_4
# Myelin_77 -> Node_70
# Myelin_78 -> Unmyelin_3
# Myelin_79 -> Node_78
# Myelin_80 -> Node_79
# Myelin_81 -> Node_80
# Myelin_82 -> Node_80
# Myelin_83 -> Node_82
# Myelin_84 -> Node_83
# Myelin_85 -> Unmyelin_6
# Myelin_86 -> Node_85
# Myelin_87 -> Node_86
# Myelin_88 -> Node_69
# Myelin_89 -> Node_88
# Myelin_90 -> Unmyelin_0
# Myelin_91 -> Node_90
# Myelin_92 -> Node_91
# Myelin_93 -> Node_92
# Myelin_94 -> Node_93
# Myelin_95 -> Node_94
# Myelin_96 -> Node_95
# Myelin_97 -> Unmyelin_8
# Myelin_98 -> Node_97
# Myelin_99 -> Node_98
# Myelin_100 -> Node_97
# Myelin_101 -> Node_100
# Myelin_102 -> Node_101
# Myelin_103 -> Node_100
# Myelin_104 -> Unmyelin_8
# Myelin_105 -> Node_104
# Myelin_106 -> Node_105
# Myelin_107 -> Node_106
# Myelin_108 -> Node_107
# Myelin_109 -> Node_108
# Myelin_110 -> Node_109
# Myelin_111 -> Node_94
# Myelin_112 -> Node_92
# Myelin_113 -> Node_112
# Myelin_114 -> Unmyelin_10
# Myelin_115 -> Unmyelin_12
# Myelin_116 -> Node_115
# Myelin_117 -> Node_116
# Myelin_118 -> Unmyelin_12
# Myelin_119 -> Node_118
# Myelin_120 -> Unmyelin_11
# Myelin_121 -> Node_114
# Myelin_122 -> Node_121
# Myelin_123 -> Node_122
# Myelin_124 -> Node_123
# Myelin_125 -> Node_124
# Myelin_126 -> Node_125
# Myelin_127 -> Node_126
# Myelin_128 -> Node_127
# Myelin_129 -> Node_128
# Myelin_130 -> Node_129
# Myelin_131 -> Node_130
# Myelin_132 -> Node_130
# Myelin_133 -> Node_125
# Myelin_134 -> Unmyelin_10
# Myelin_135 -> Node_134
# Myelin_136 -> Node_135
# Myelin_137 -> Node_135
# Myelin_138 -> Node_137
# Myelin_139 -> Node_138
# Myelin_140 -> Node_137
# Myelin_141 -> Node_140
# Myelin_142 -> Node_141
# Myelin_143 -> Node_142
# Myelin_144 -> Node_140
# Myelin_145 -> Node_144
# Myelin_146 -> Node_145
# Myelin_147 -> Node_146
# Myelin_148 -> Node_8
# Myelin_149 -> Node_148
# Myelin_150 -> Node_149
# Myelin_151 -> Node_150
# Myelin_152 -> Node_149
# Myelin_153 -> Node_152
# Myelin_154 -> Node_153
# Myelin_155 -> Node_154
# Myelin_156 -> Node_155
# Myelin_157 -> Node_156
# Myelin_158 -> Node_157
# Myelin_159 -> Node_158
# Myelin_160 -> Node_159
# Myelin_161 -> Node_160
# Myelin_162 -> Node_161
# Myelin_163 -> Node_161
# Myelin_164 -> Node_163
# Myelin_165 -> Node_164
# Myelin_166 -> Node_165
# Myelin_167 -> Node_166
# Myelin_168 -> Node_167
# Myelin_169 -> Node_168
# Myelin_170 -> Node_152
# Myelin_171 -> Node_170
# Myelin_172 -> Node_171
# Myelin_173 -> Node_172
# Myelin_174 -> Node_173
# Myelin_175 -> Node_173
# Myelin_176 -> Node_171
# Myelin_177 -> Node_176
# Myelin_178 -> Node_177
# Myelin_179 -> Node_178
# Myelin_180 -> Node_179
# Myelin_181 -> Node_7
# Myelin_182 -> Node_181
# Myelin_183 -> Unmyelin_15
# Myelin_184 -> Unmyelin_16
# Myelin_185 -> Node_184
# Myelin_186 -> Node_185
# Myelin_187 -> Node_185
# Myelin_188 -> Node_187
# Myelin_189 -> Unmyelin_16
# Myelin_190 -> Node_183
# Myelin_191 -> Node_190
# Myelin_192 -> Unmyelin_15
# Myelin_193 -> Node_192
# Myelin_194 -> Node_192
# Myelin_195 -> Node_194
# Myelin_196 -> Node_195
# Myelin_197 -> Unmyelin_18
# Myelin_198 -> Node_197
# Myelin_199 -> Node_182
# Myelin_200 -> Node_199
# Myelin_201 -> Node_200
# Myelin_202 -> Node_201
# Myelin_203 -> Unmyelin_22
# Myelin_204 -> Node_203
# Myelin_205 -> Node_204
# Myelin_206 -> Node_205
# Myelin_207 -> Node_206
# Myelin_208 -> Node_207
# Myelin_209 -> Node_205
# Myelin_210 -> Node_209
# Myelin_211 -> Node_210
# Myelin_212 -> Unmyelin_23
# Myelin_213 -> Unmyelin_23
# Myelin_214 -> Node_213
# Myelin_215 -> Unmyelin_24
# Myelin_216 -> Node_215
# Myelin_217 -> Unmyelin_24
# Myelin_218 -> Node_214
# Myelin_219 -> Node_218
# Myelin_220 -> Node_219
# Myelin_221 -> Node_204
# Myelin_222 -> Node_221
# Myelin_223 -> Node_222
# Myelin_224 -> Node_223
# Myelin_225 -> Unmyelin_30
# Myelin_226 -> Unmyelin_30
# Myelin_227 -> Node_226
# Myelin_228 -> Node_227
# Myelin_229 -> Node_228
# Myelin_230 -> Node_229
# Myelin_231 -> Node_230
# Myelin_232 -> Node_231
# Myelin_233 -> Unmyelin_22
# Myelin_234 -> Node_233
# Myelin_235 -> Node_234
# Myelin_236 -> Node_235
# Myelin_237 -> Node_236
# Myelin_238 -> Node_237
# Myelin_239 -> Node_238
# Myelin_240 -> Node_238
# Myelin_241 -> Node_236
# Myelin_242 -> Node_241
# Myelin_243 -> Unmyelin_21
# Myelin_244 -> Node_243
# Myelin_245 -> Node_244
# Myelin_246 -> Node_245
# Myelin_247 -> Node_246
# Myelin_248 -> Node_247
# Myelin_249 -> Node_248
# Myelin_250 -> Node_247
# Myelin_251 -> Node_245
# Myelin_252 -> Node_244
# Myelin_253 -> Node_252
# Myelin_254 -> Unmyelin_32
# Myelin_255 -> Node_254
# Myelin_256 -> Node_255
# Myelin_257 -> Unmyelin_33
# Myelin_258 -> Node_257
# Myelin_259 -> Node_258
# Myelin_260 -> Node_259
# Myelin_261 -> Node_259
# Myelin_262 -> Node_258
# Myelin_263 -> Node_262
# Myelin_264 -> Unmyelin_33
# Myelin_265 -> Node_264
# Myelin_266 -> Node_265
# Myelin_267 -> Node_266
# Myelin_268 -> Node_267
# Myelin_269 -> Node_268
# Myelin_270 -> Node_269
# Myelin_271 -> Node_264
# Myelin_272 -> Node_271
# Myelin_273 -> Unmyelin_35
# Myelin_274 -> Node_273
# Myelin_275 -> Node_274
# Myelin_276 -> Node_275
# Myelin_277 -> Node_276
# Myelin_278 -> Node_277
# Myelin_279 -> Node_278
# Myelin_280 -> Node_279
# Myelin_281 -> Node_280
# Myelin_282 -> Unmyelin_35
# Myelin_283 -> Node_272
# Myelin_284 -> Node_283
# Myelin_285 -> Node_284
# Myelin_286 -> Node_285
# Myelin_287 -> Node_271
# Myelin_288 -> Node_287
# Myelin_289 -> Node_288
# Myelin_290 -> Node_289
# Myelin_291 -> Node_290
# Myelin_292 -> Node_291
# Myelin_293 -> Node_292
# Myelin_294 -> Node_293
# Myelin_295 -> Node_294
# Myelin_296 -> Node_295
# Myelin_297 -> Node_296
# Myelin_298 -> Node_297
# Myelin_299 -> Node_298
# Myelin_300 -> Node_299
# Myelin_301 -> Node_287
# Myelin_302 -> Node_301
# Myelin_303 -> Node_302
# Myelin_304 -> Node_303
# Myelin_305 -> Node_304
# Myelin_306 -> Node_305
# Myelin_307 -> Node_306
# Myelin_308 -> Node_307
# Myelin_309 -> Node_308
# Myelin_310 -> Unmyelin_32
# Myelin_311 -> Node_310
# Myelin_312 -> Node_311
# Myelin_313 -> Node_312
# Myelin_314 -> Node_313
# Myelin_315 -> Node_314
# Myelin_316 -> Unmyelin_36
# Myelin_317 -> Node_316
# Myelin_318 -> Node_317
# Myelin_319 -> Unmyelin_37
# Myelin_320 -> Node_319
# Myelin_321 -> Unmyelin_38
# Myelin_322 -> Node_321
# Myelin_323 -> Unmyelin_38
# Myelin_324 -> Node_323
# Myelin_325 -> Node_320
# Myelin_326 -> Node_325
# Myelin_327 -> Unmyelin_37
# Myelin_328 -> Node_327
# Myelin_329 -> Node_328
# Myelin_330 -> Node_329
# Myelin_331 -> Node_330
# Myelin_332 -> Node_329
# Myelin_333 -> Node_318
# Myelin_334 -> Node_333
# Myelin_335 -> Unmyelin_40
# Myelin_336 -> Node_335
# Myelin_337 -> Node_336
# Myelin_338 -> Node_337
# Myelin_339 -> Node_338
# Myelin_340 -> Node_339
# Myelin_341 -> Node_340
# Myelin_342 -> Node_341
# Myelin_343 -> Node_342
# Myelin_344 -> Node_343
# Myelin_345 -> Node_335
# Myelin_346 -> Node_345
# Myelin_347 -> Node_346
# Myelin_348 -> Node_347
# Myelin_349 -> Node_348
# Myelin_350 -> Node_349
# Myelin_351 -> Unmyelin_40
# Myelin_352 -> Unmyelin_41
# Myelin_353 -> Node_352
# Myelin_354 -> Unmyelin_41
# Myelin_355 -> Node_354
# Myelin_356 -> Node_351
# Myelin_357 -> Node_356
# Myelin_358 -> Node_357
# Myelin_359 -> Node_358
# Node_0 -> Myelin_0
# Node_1 -> Myelin_1
# Node_2 -> Myelin_2
# Node_3 -> Myelin_3
# Node_4 -> Myelin_4
# Node_5 -> Myelin_5
# Node_6 -> Myelin_6
# Node_7 -> Myelin_7
# Node_8 -> Myelin_8
# Node_9 -> Myelin_9
# Node_10 -> Myelin_10
# Node_11 -> Myelin_11
# Node_12 -> Myelin_12
# Node_13 -> Myelin_13
# Node_14 -> Myelin_14
# Node_15 -> Myelin_15
# Node_16 -> Myelin_16
# Node_17 -> Myelin_17
# Node_18 -> Myelin_18
# Node_19 -> Myelin_19
# Node_20 -> Myelin_20
# Node_21 -> Myelin_21
# Node_22 -> Myelin_22
# Node_23 -> Myelin_23
# Node_24 -> Myelin_24
# Node_25 -> Myelin_25
# Node_26 -> Myelin_26
# Node_27 -> Myelin_27
# Node_28 -> Myelin_28
# Node_29 -> Myelin_29
# Node_30 -> Myelin_30
# Node_31 -> Myelin_31
# Node_32 -> Myelin_32
# Node_33 -> Myelin_33
# Node_34 -> Myelin_34
# Node_35 -> Myelin_35
# Node_36 -> Myelin_36
# Node_37 -> Myelin_37
# Node_38 -> Myelin_38
# Node_39 -> Myelin_39
# Node_40 -> Myelin_40
# Node_41 -> Myelin_41
# Node_42 -> Myelin_42
# Node_43 -> Myelin_43
# Node_44 -> Myelin_44
# Node_45 -> Myelin_45
# Node_46 -> Myelin_46
# Node_47 -> Myelin_47
# Node_48 -> Myelin_48
# Node_49 -> Myelin_49
# Node_50 -> Myelin_50
# Node_51 -> Myelin_51
# Node_52 -> Myelin_52
# Node_53 -> Myelin_53
# Node_54 -> Myelin_54
# Node_55 -> Myelin_55
# Node_56 -> Myelin_56
# Node_57 -> Myelin_57
# Node_58 -> Myelin_58
# Node_59 -> Myelin_59
# Node_60 -> Myelin_60
# Node_61 -> Myelin_61
# Node_62 -> Myelin_62
# Node_63 -> Myelin_63
# Node_64 -> Myelin_64
# Node_65 -> Myelin_65
# Node_66 -> Myelin_66
# Node_67 -> Myelin_67
# Node_68 -> Myelin_68
# Node_69 -> Myelin_69
# Node_70 -> Myelin_70
# Node_71 -> Myelin_71
# Node_72 -> Myelin_72
# Node_73 -> Myelin_73
# Node_74 -> Myelin_74
# Node_75 -> Myelin_75
# Node_76 -> Myelin_76
# Node_77 -> Myelin_77
# Node_78 -> Myelin_78
# Node_79 -> Myelin_79
# Node_80 -> Myelin_80
# Node_81 -> Myelin_81
# Node_82 -> Myelin_82
# Node_83 -> Myelin_83
# Node_84 -> Myelin_84
# Node_85 -> Myelin_85
# Node_86 -> Myelin_86
# Node_87 -> Myelin_87
# Node_88 -> Myelin_88
# Node_89 -> Myelin_89
# Node_90 -> Myelin_90
# Node_91 -> Myelin_91
# Node_92 -> Myelin_92
# Node_93 -> Myelin_93
# Node_94 -> Myelin_94
# Node_95 -> Myelin_95
# Node_96 -> Myelin_96
# Node_97 -> Myelin_97
# Node_98 -> Myelin_98
# Node_99 -> Myelin_99
# Node_100 -> Myelin_100
# Node_101 -> Myelin_101
# Node_102 -> Myelin_102
# Node_103 -> Myelin_103
# Node_104 -> Myelin_104
# Node_105 -> Myelin_105
# Node_106 -> Myelin_106
# Node_107 -> Myelin_107
# Node_108 -> Myelin_108
# Node_109 -> Myelin_109
# Node_110 -> Myelin_110
# Node_111 -> Myelin_111
# Node_112 -> Myelin_112
# Node_113 -> Myelin_113
# Node_114 -> Myelin_114
# Node_115 -> Myelin_115
# Node_116 -> Myelin_116
# Node_117 -> Myelin_117
# Node_118 -> Myelin_118
# Node_119 -> Myelin_119
# Node_120 -> Myelin_120
# Node_121 -> Myelin_121
# Node_122 -> Myelin_122
# Node_123 -> Myelin_123
# Node_124 -> Myelin_124
# Node_125 -> Myelin_125
# Node_126 -> Myelin_126
# Node_127 -> Myelin_127
# Node_128 -> Myelin_128
# Node_129 -> Myelin_129
# Node_130 -> Myelin_130
# Node_131 -> Myelin_131
# Node_132 -> Myelin_132
# Node_133 -> Myelin_133
# Node_134 -> Myelin_134
# Node_135 -> Myelin_135
# Node_136 -> Myelin_136
# Node_137 -> Myelin_137
# Node_138 -> Myelin_138
# Node_139 -> Myelin_139
# Node_140 -> Myelin_140
# Node_141 -> Myelin_141
# Node_142 -> Myelin_142
# Node_143 -> Myelin_143
# Node_144 -> Myelin_144
# Node_145 -> Myelin_145
# Node_146 -> Myelin_146
# Node_147 -> Myelin_147
# Node_148 -> Myelin_148
# Node_149 -> Myelin_149
# Node_150 -> Myelin_150
# Node_151 -> Myelin_151
# Node_152 -> Myelin_152
# Node_153 -> Myelin_153
# Node_154 -> Myelin_154
# Node_155 -> Myelin_155
# Node_156 -> Myelin_156
# Node_157 -> Myelin_157
# Node_158 -> Myelin_158
# Node_159 -> Myelin_159
# Node_160 -> Myelin_160
# Node_161 -> Myelin_161
# Node_162 -> Myelin_162
# Node_163 -> Myelin_163
# Node_164 -> Myelin_164
# Node_165 -> Myelin_165
# Node_166 -> Myelin_166
# Node_167 -> Myelin_167
# Node_168 -> Myelin_168
# Node_169 -> Myelin_169
# Node_170 -> Myelin_170
# Node_171 -> Myelin_171
# Node_172 -> Myelin_172
# Node_173 -> Myelin_173
# Node_174 -> Myelin_174
# Node_175 -> Myelin_175
# Node_176 -> Myelin_176
# Node_177 -> Myelin_177
# Node_178 -> Myelin_178
# Node_179 -> Myelin_179
# Node_180 -> Myelin_180
# Node_181 -> Myelin_181
# Node_182 -> Myelin_182
# Node_183 -> Myelin_183
# Node_184 -> Myelin_184
# Node_185 -> Myelin_185
# Node_186 -> Myelin_186
# Node_187 -> Myelin_187
# Node_188 -> Myelin_188
# Node_189 -> Myelin_189
# Node_190 -> Myelin_190
# Node_191 -> Myelin_191
# Node_192 -> Myelin_192
# Node_193 -> Myelin_193
# Node_194 -> Myelin_194
# Node_195 -> Myelin_195
# Node_196 -> Myelin_196
# Node_197 -> Myelin_197
# Node_198 -> Myelin_198
# Node_199 -> Myelin_199
# Node_200 -> Myelin_200
# Node_201 -> Myelin_201
# Node_202 -> Myelin_202
# Node_203 -> Myelin_203
# Node_204 -> Myelin_204
# Node_205 -> Myelin_205
# Node_206 -> Myelin_206
# Node_207 -> Myelin_207
# Node_208 -> Myelin_208
# Node_209 -> Myelin_209
# Node_210 -> Myelin_210
# Node_211 -> Myelin_211
# Node_212 -> Myelin_212
# Node_213 -> Myelin_213
# Node_214 -> Myelin_214
# Node_215 -> Myelin_215
# Node_216 -> Myelin_216
# Node_217 -> Myelin_217
# Node_218 -> Myelin_218
# Node_219 -> Myelin_219
# Node_220 -> Myelin_220
# Node_221 -> Myelin_221
# Node_222 -> Myelin_222
# Node_223 -> Myelin_223
# Node_224 -> Myelin_224
# Node_225 -> Myelin_225
# Node_226 -> Myelin_226
# Node_227 -> Myelin_227
# Node_228 -> Myelin_228
# Node_229 -> Myelin_229
# Node_230 -> Myelin_230
# Node_231 -> Myelin_231
# Node_232 -> Myelin_232
# Node_233 -> Myelin_233
# Node_234 -> Myelin_234
# Node_235 -> Myelin_235
# Node_236 -> Myelin_236
# Node_237 -> Myelin_237
# Node_238 -> Myelin_238
# Node_239 -> Myelin_239
# Node_240 -> Myelin_240
# Node_241 -> Myelin_241
# Node_242 -> Myelin_242
# Node_243 -> Myelin_243
# Node_244 -> Myelin_244
# Node_245 -> Myelin_245
# Node_246 -> Myelin_246
# Node_247 -> Myelin_247
# Node_248 -> Myelin_248
# Node_249 -> Myelin_249
# Node_250 -> Myelin_250
# Node_251 -> Myelin_251
# Node_252 -> Myelin_252
# Node_253 -> Myelin_253
# Node_254 -> Myelin_254
# Node_255 -> Myelin_255
# Node_256 -> Myelin_256
# Node_257 -> Myelin_257
# Node_258 -> Myelin_258
# Node_259 -> Myelin_259
# Node_260 -> Myelin_260
# Node_261 -> Myelin_261
# Node_262 -> Myelin_262
# Node_263 -> Myelin_263
# Node_264 -> Myelin_264
# Node_265 -> Myelin_265
# Node_266 -> Myelin_266
# Node_267 -> Myelin_267
# Node_268 -> Myelin_268
# Node_269 -> Myelin_269
# Node_270 -> Myelin_270
# Node_271 -> Myelin_271
# Node_272 -> Myelin_272
# Node_273 -> Myelin_273
# Node_274 -> Myelin_274
# Node_275 -> Myelin_275
# Node_276 -> Myelin_276
# Node_277 -> Myelin_277
# Node_278 -> Myelin_278
# Node_279 -> Myelin_279
# Node_280 -> Myelin_280
# Node_281 -> Myelin_281
# Node_282 -> Myelin_282
# Node_283 -> Myelin_283
# Node_284 -> Myelin_284
# Node_285 -> Myelin_285
# Node_286 -> Myelin_286
# Node_287 -> Myelin_287
# Node_288 -> Myelin_288
# Node_289 -> Myelin_289
# Node_290 -> Myelin_290
# Node_291 -> Myelin_291
# Node_292 -> Myelin_292
# Node_293 -> Myelin_293
# Node_294 -> Myelin_294
# Node_295 -> Myelin_295
# Node_296 -> Myelin_296
# Node_297 -> Myelin_297
# Node_298 -> Myelin_298
# Node_299 -> Myelin_299
# Node_300 -> Myelin_300
# Node_301 -> Myelin_301
# Node_302 -> Myelin_302
# Node_303 -> Myelin_303
# Node_304 -> Myelin_304
# Node_305 -> Myelin_305
# Node_306 -> Myelin_306
# Node_307 -> Myelin_307
# Node_308 -> Myelin_308
# Node_309 -> Myelin_309
# Node_310 -> Myelin_310
# Node_311 -> Myelin_311
# Node_312 -> Myelin_312
# Node_313 -> Myelin_313
# Node_314 -> Myelin_314
# Node_315 -> Myelin_315
# Node_316 -> Myelin_316
# Node_317 -> Myelin_317
# Node_318 -> Myelin_318
# Node_319 -> Myelin_319
# Node_320 -> Myelin_320
# Node_321 -> Myelin_321
# Node_322 -> Myelin_322
# Node_323 -> Myelin_323
# Node_324 -> Myelin_324
# Node_325 -> Myelin_325
# Node_326 -> Myelin_326
# Node_327 -> Myelin_327
# Node_328 -> Myelin_328
# Node_329 -> Myelin_329
# Node_330 -> Myelin_330
# Node_331 -> Myelin_331
# Node_332 -> Myelin_332
# Node_333 -> Myelin_333
# Node_334 -> Myelin_334
# Node_335 -> Myelin_335
# Node_336 -> Myelin_336
# Node_337 -> Myelin_337
# Node_338 -> Myelin_338
# Node_339 -> Myelin_339
# Node_340 -> Myelin_340
# Node_341 -> Myelin_341
# Node_342 -> Myelin_342
# Node_343 -> Myelin_343
# Node_344 -> Myelin_344
# Node_345 -> Myelin_345
# Node_346 -> Myelin_346
# Node_347 -> Myelin_347
# Node_348 -> Myelin_348
# Node_349 -> Myelin_349
# Node_350 -> Myelin_350
# Node_351 -> Myelin_351
# Node_352 -> Myelin_352
# Node_353 -> Myelin_353
# Node_354 -> Myelin_354
# Node_355 -> Myelin_355
# Node_356 -> Myelin_356
# Node_357 -> Myelin_357
# Node_358 -> Myelin_358
# Node_359 -> Myelin_359
# Unmyelin_0 -> Node_10
# Unmyelin_1 -> Node_17
# Unmyelin_2 -> Node_55
# Unmyelin_3 -> Node_69
# Unmyelin_4 -> Node_70
# Unmyelin_5 -> Node_74
# Unmyelin_6 -> Node_83
# Unmyelin_7 -> Unmyelin_6
# Unmyelin_8 -> Node_95
# Unmyelin_9 -> Node_107
# Unmyelin_10 -> Node_10
# Unmyelin_11 -> Node_114
# Unmyelin_12 -> Unmyelin_11
# Unmyelin_13 -> Node_121
# Unmyelin_14 -> Node_168
# Unmyelin_15 -> Node_182
# Unmyelin_16 -> Node_183
# Unmyelin_17 -> Node_187
# Unmyelin_18 -> Node_195
# Unmyelin_19 -> Unmyelin_18
# Unmyelin_20 -> Node_3
# Unmyelin_21 -> Unmyelin_20
# Unmyelin_22 -> Unmyelin_21
# Unmyelin_23 -> Node_210
# Unmyelin_24 -> Node_214
# Unmyelin_25 -> Node_215
# Unmyelin_26 -> Node_217
# Unmyelin_27 -> Node_217
# Unmyelin_28 -> Node_219
# Unmyelin_29 -> Node_209
# Unmyelin_30 -> Node_223
# Unmyelin_31 -> Unmyelin_20
# Unmyelin_32 -> Unmyelin_31
# Unmyelin_33 -> Unmyelin_32
# Unmyelin_34 -> Node_262
# Unmyelin_35 -> Node_272
# Unmyelin_36 -> Unmyelin_31
# Unmyelin_37 -> Node_318
# Unmyelin_38 -> Node_320
# Unmyelin_39 -> Node_321
# Unmyelin_40 -> Unmyelin_36
# Unmyelin_41 -> Node_351

# %%
sim.analysis.plot2Dnet(figSize=(5, 4), fontSize=12)
# Out:
# Plotting 2D representation of network cell locations and connections...
# (<Figure size 500x400 with 1 Axes>,
#  {'include': ['allCells'],
#   'posX': [210],
#   'posY': [857],
#   'posXpre': [],
#   'posXpost': [],
#   'posYpre': [],
#   'posYpost': []})
